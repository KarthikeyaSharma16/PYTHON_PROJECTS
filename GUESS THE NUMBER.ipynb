# %%
import random as r
x = r.randint(1,100)
def randi():
    guess = int(input("Enter a number to guess: "))
    return guess

no_of_attempts = 0
guess = randi()

while True:
    if guess == x:
        break
    elif guess != x:
        if guess > x:
            print("Go lower!")
        elif guess < x:
            print("Go higher!")
        no_of_attempts += 1
        guess = randi()
    
print(f"You have guessed the number! Number of attempts taken to guess the number is {no_of_attempts}")
# Out:
# Enter a number to guess: 10
# Go higher!
# Enter a number to guess: 20
# Go higher!
# Enter a number to guess: 30
# Go lower!
# Enter a number to guess: 28
# Go lower!
# Enter a number to guess: 25
# Go lower!
# Enter a number to guess: 24
# Go lower!
# Enter a number to guess: 21
# Go higher!
# Enter a number to guess: 22
# Go higher!
# Enter a number to guess: 23
# You have guessed the number! Number of attempts taken to guess the number is 8

# %%
import random as random_number
import sys
def roll_dice_and_compute_sum(ndice):
    print ('rolldce')
    return sum([random_number.randint(1, 6) for i in range(ndice)])
def computer_guess(ndice):
    print ('comp')
    return random_number.randint(ndice, 6*ndice)
def player_guess(ndice):
    print ('pguess')
    return int(input('Guess the sum of the no of eyes in the next throw: '))
def play_one_round(ndice, capital, guess_function):
    print ('play1')
    guess = guess_function(ndice)
    throw = roll_dice_and_compute_sum(ndice)
    print(throw)
    if guess == throw:
        capital += guess
    else:
        capital -= 1
    return capital, throw, guess
winner = 0
def play(nrounds, ndice=2):
    print ('play')
    #start capital
    player_capital = computer_capital = nrounds  # start capital

    for i in range(nrounds):
        player_capital, throw, guess = play_one_round(ndice, player_capital, player_guess)
        print ('YOU guessed %d, got %d' % (guess, throw))
        if player_capital == 0:
            print('Machine won!', sys.exit(0))            
        computer_capital, throw, guess = play_one_round(ndice, computer_capital, computer_guess)
        print ('Machine guessed %d, got %d' % (guess, throw))
        if computer_capital == 0:
             print('You won!', sys.exit(0))
        print ('Status: you have %d euros, machine has %d euros\n' % (player_capital, computer_capital))

    if computer_capital > player_capital:
        winner = 'Machine'
    else:
        winner = 'You'
    print (winner, 'won!')
play(2,4)
# Out:
# play
# play1
# pguess
# Guess the sum of the no of eyes in the next throw: 5
# rolldce
# 16
# YOU guessed 5, got 16
# play1
# comp
# rolldce
# 12
# Machine guessed 13, got 12
# Status: you have 1 euros, machine has 1 euros
#
# play1
# pguess
# Guess the sum of the no of eyes in the next throw: 5
# rolldce
# 15
# YOU guessed 5, got 15
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
